# %%
# %matplotlib inline

# %%
# %run mainTest.py
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# Predicted class: notumor

# %%
evaluate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 evaluate()
#
# NameError: name 'evaluate' is not defined

# %%
# Cell 1: setup
# %matplotlib inline
import os
print("CWD:", os.getcwd())
# Out:
# CWD: C:\Users\Siddharth\Desktop\Major Project (ML model)

# %%
# Cell 2: train and capture history
from tensorflow.keras.models import load_model
# run training and grab the History
# this executes maintrain.py and returns the `history` variable
history = %run -o maintrain.py
# Out:
# UsageError: option -o not recognized ( allowed: "nidtN:b:pD:l:rs:T:em:G" )
