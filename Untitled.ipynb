# %%
# %matplotlib inline

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Siddharth\Desktop\Major Project (ML model)

# %%
# %run maintest.py
# Out:
#   File ~\Desktop\Major Project (ML model)\mainTest.py:1
#     !python maintest.py
#     ^
# SyntaxError: invalid syntax

# %%
# %run mainTest.py
# Out:
#   File ~\Desktop\Major Project (ML model)\mainTest.py:1
#     !python maintest.py
#     ^
# SyntaxError: invalid syntax

# %%
# !python mainTest.py
# Out:
#   File "C:\Users\Siddharth\Desktop\Major Project (ML model)\mainTest.py", line 1
#     !python maintest.py
#     ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
# %run maintest.py
# Out:
#   File ~\Desktop\Major Project (ML model)\mainTest.py:1
#     !python maintest.py
#     ^
# SyntaxError: invalid syntax

# %%
# !python mainTest.py
# Out:
#   File "C:\Users\Siddharth\Desktop\Major Project (ML model)\mainTest.py", line 1
#     !python maintest.py
#     ^
# SyntaxError: invalid syntax

# %%
python mainTest.py
# Out:
#   Cell In[15], line 1
#     python mainTest.py
#            ^
# SyntaxError: invalid syntax

# %%
python app.py
# Out:
#   Cell In[17], line 1
#     python app.py
#            ^
# SyntaxError: invalid syntax

# %%
# !python mainTrain.py
# Out:
# Epoch 1/50
#
#   1/143 ==================== 6:30 3s/step - accuracy: 0.1562 - loss: 1.405
#   3/143 ==================== 7s 53ms/step - accuracy: 0.1962 - loss: 1.412
#   4/143 ==================== 7s 53ms/step - accuracy: 0.2155 - loss: 1.402
#   5/143 ==================== 7s 54ms/step - accuracy: 0.2224 - loss: 1.401
#   7/143 ==================== 6s 51ms/step - accuracy: 0.2349 - loss: 1.396
#   9/143 ==================== 6s 50ms/step - accuracy: 0.2456 - loss: 1.391
#  11/143 ==================== 6s 48ms/step - accuracy: 0.2499 - loss: 1.388
#  12/143 ==================== 6s 48ms/step - accuracy: 0.2519 - loss: 1.386
#  14/143 ==================== 6s 48ms/step - accuracy: 0.2556 - loss: 1.382
#  16/143 ==================== 5s 47ms/step - accuracy: 0.2587 - loss: 1.379
#  18/143 ==================== 5s 47ms/step - accuracy: 0.2622 - loss: 1.375
#  20/143 ==================== 5s 46ms/step - accuracy: 0.2663 - loss: 1.371
# ...

# %%
# !python mainTest.py
# Out:
#   File "C:\Users\Siddharth\Desktop\Major Project (ML model)\mainTest.py", line 1
#     !python maintest.py
#     ^
# SyntaxError: invalid syntax

# %%
import os
print("Notebook cwd:", os.getcwd())
# !ls
# Out:
# Notebook cwd: C:\Users\Siddharth\Desktop\Major Project (ML model)
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
print("Notebook cwd:", os.getcwd())
# Out:
# Notebook cwd: C:\Users\Siddharth\Desktop\Major Project (ML model)

# %%
# %run mainTest.py
# Out:
#   File ~\Desktop\Major Project (ML model)\mainTest.py:1
#     !python maintest.py
#     ^
# SyntaxError: invalid syntax

# %%
# %run mainTest.py
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Predicted class: notumor
